# %% [markdown]
# # 📘 Problemas de Optimización No Lineal con Restricciones
# Aplicados a Ingeniería Electrónica y Telecomunicaciones
#
# ---
#
# ## 🔹 Problema 1: Optimización de Potencia en un Amplificador
# Un amplificador de potencia debe operar en un rango seguro de voltaje y corriente. La eficiencia del amplificador está dada por:
#
# $$
# \eta(V,I) = \frac{V \cdot I}{V^2 + 2I^2 + 5}
# $$
#
# **Restricciones:**
# - $ V \cdot I \geq 10 $
# - $ V \leq 15 $
# - $ I \geq 0.5 $
# - $ V^2 + I^2 = 225 $
#
# **Objetivo:**
# Maximizar $\eta(V,I)$.
#
# ---
#
# ## 🔹 Problema 2: Asignación de Potencia en un Sistema MIMO
# En un sistema MIMO de 2 antenas, la **capacidad del canal** es:
#
# $$
# C(P_1,P_2) = \log_2 \left( 1 + h_1 P_1 + h_2 P_2 \right) - \alpha (P_1^2 + P_2^2)
# $$
#
# Con parámetros: $h_1=2, h_2=3, \alpha=0.05$.
#
# **Restricciones:**
# - $P_1 + P_2 \leq 10$
# - $P_1 \geq 1, \; P_2 \geq 1$
# - $P_1^2 + P_2^2 = 50$
#
# **Objetivo:**
# Maximizar $C(P_1,P_2)$.
#
# ---
#
# ## 🔹 Problema 3: Diseño de un Filtro Activo
# Se desea diseñar un filtro pasa-bajas con función de costo:
#
# $$
# J(R,C) = (f_c - f_d)^2 + 0.01(R^2 + C^2)
# $$
#
# Donde:
# - $f_c = \frac{1}{2 \pi R C}$,
# - $f_d = 1000 \, Hz$.
#
# **Restricciones:**
# - $0.5 \leq R \leq 10$
# - $0.01 \leq C \leq 1$
# - $R \cdot C \geq 0.1$
# - $R + 2C = 5$
#
# **Objetivo:**
# Minimizar $J(R,C)$.
#
# ---
#
# ## 🔹 Problema 4: Optimización en Enlace Óptico
# En un sistema óptico, la probabilidad de error de bit (BER) es:
#
# $$
# BER(P,M) = \frac{1}{M} e^{-\beta P} + \gamma P^2
# $$
#
# Con parámetros: $\beta = 0.8, \gamma = 0.01$, y $M \in \{4,8,16\}$.
#
# **Restricciones:**
# - $2 \leq P \leq 20 $
# - $ P \cdot M = 50 $
#
# **Objetivo:**
# Minimizar $BER(P,M)$.
#
# ---
#
# ## 🔹 Problema 5: Optimización de Cobertura en una Red Celular
# La intensidad de señal recibida se modela como:
#
# $$
# S(P_1,P_2) = \sqrt{aP_1} + \sqrt{bP_2} - 0.1(P_1^2 + P_2^2)
# $$
#
# Con parámetros: $a=4, b=3$.
#
# **Restricciones:**
# - $P_1 + P_2 \leq 15 $
# - $P_1, P_2 \geq 0 $
# - $P_1^2 + P_2^2 = 100$
#
# **Objetivo:**
# Maximizar $S(P_1,P_2)$.
