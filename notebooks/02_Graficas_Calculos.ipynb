555555556,-0.15151515151515152,-0.14747474747474748,-0.14343434343434344,-0.1393939393939394,-0.13535353535353536,-0.13131313131313133,-0.1272727272727273,-0.12323232323232325,-0.11919191919191921,-0.11515151515151516,-0.11111111111111112,-0.10707070707070708,-0.10303030303030304,-0.098989898989899,-0.09494949494949496,-0.09090909090909093,-0.08686868686868687,-0.08282828282828283,-0.0787878787878788,-0.07474747474747476,-0.07070707070707072,-0.06666666666666668,-0.06262626262626264,-0.0585858585858586,-0.054545454545454564,-0.050505050505050525,-0.046464646464646486,-0.04242424242424245,-0.03838383838383841,-0.03434343434343434,-0.030303030303030304,-0.026262626262626265,-0.022222222222222227,-0.018181818181818188,-0.01414141414141415,-0.01010101010101011,-0.006060606060606072,-0.002020202020202033,0.0020202020202020055,0.006060606060606044,0.010101010101010083,0.014141414141414121,0.01818181818181816,0.0222222222222222,0.026262626262626265,0.030303030303030304,0.03434343434343434,0.03838383838383838,0.04242424242424242,0.04646464646464646,0.0505050505050505,0.05454545454545451,0.058585858585858575,0.06262626262626264,0.06666666666666665,0.07070707070707072,0.07474747474747473,0.078 ...

# %% [markdown]
# # Calculo con Sympy de Hessiana
# https://docs.sympy.org/latest/modules/matrices/matrices.html

# %%
from sympy import Function, hessian, pprint
from sympy.abc import x, y
f = x**2 + y**3
g = [f.diff(x), f.diff(y)]
print("El gradiente es: ")
pprint(g)
print("La Hessiana es: ")
h = hessian(f, (x, y))
pprint(h)
# Out:
# El gradiente es:
# ⎡        2⎤
# ⎣2⋅x, 3⋅y ⎦
# La Hessiana es:
# ⎡2   0 ⎤
# ⎢      ⎥
# ⎣0  6⋅y⎦

# %% [markdown]
# # Calculo con autograd
# https://github.com/HIPS/autograd/blob/master/docs/tutorial.md

# %%
import autograd 
f = lambda x,y: x**2 + y**3
g = autograd.grad(f)
print(g(0.1,0.2))
h = autograd.hessian(f)
print(h(0.1,0.2))
# Out:
# 0.2
# 2.0

# %% [markdown]
# # Calculo con JAX
# https://jax.readthedocs.io/en/latest/notebooks/autodiff_cookbook.html

# %%
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random

# %%
f = lambda x: x[0]**2 + x[1]**3

# %%
grad_f = grad(f)
print(grad_f([0.1,0.2]))
# Out:
# [DeviceArray(0.2, dtype=float32, weak_type=True), DeviceArray(0.12, dtype=float32, weak_type=True)]

# %%
from jax import jacfwd, jacrev
def hessian(f):
    return jacfwd(jacrev(f))

# %%
H1 = hessian(f)
H1([0.1,0.2])
# Out:
# [[DeviceArray(2., dtype=float32, weak_type=True),
#   DeviceArray(0., dtype=float32, weak_type=True)],
#  [DeviceArray(0., dtype=float32, weak_type=True),
#   DeviceArray(1.2, dtype=float32, weak_type=True)]]
